# %% [markdown]
# ## Import libraries

# %%
# !git clone https://github.com/rajeevratan84/image-segmentation-keras.git
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 1165, done.
# remote: Total 1165 (delta 0), reused 0 (delta 0), pack-reused 1165 (from 1)
# Receiving objects: 100% (1165/1165), 3.29 MiB | 9.62 MiB/s, done.
# Resolving deltas: 100% (752/752), done.

# %%
# %cd image-segmentation-keras
# Out:
# /kaggle/working/image-segmentation-keras

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
from keras.callbacks import ModelCheckpoint
from IPython.display import Image
import tensorflow as tf
from tensorflow.keras import backend as K
from keras_segmentation.models.unet import resnet50_unet
from tensorflow.keras.optimizers import Adam
import time

# %% [markdown]
# ## check image-mask pairs

# %%
image_train_list = os.listdir('/kaggle/input/beach-litter-dataset/Beachlitter_prepped/train_images')
anns_train_list = os.listdir('/kaggle/input/beach-litter-dataset/Beachlitter_masks_litter_only/train_litter_mask')
image_val_list = os.listdir('/kaggle/input/beach-litter-dataset/Beachlitter_prepped/val_images')
anns_val_list = os.listdir('/kaggle/input/beach-litter-dataset/Beachlitter_masks_litter_only/val_litter_mask')

image_train_list = [substring[:6] for substring in image_train_list]
anns_train_list = [substring[:6] for substring in anns_train_list]
image_val_list = [substring[:6] for substring in image_val_list]
anns_val_list = [substring[:6] for substring in anns_val_list]

print('number of train data pairs: ', len(set(image_train_list).intersection(anns_train_list)))
print('number of validation data pairs: ', len(set(image_val_list).intersection(anns_val_list)))
del image_train_list, anns_train_list, image_val_list, anns_val_list
# Out:
# number of train data pairs:  2240
# number of validation data pairs:  560

# %% [markdown]
# ## Dice loss definition

# %%
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Calculate Dice Loss between the ground truth and predictions.

    Parameters:
    - y_true: Ground truth labels (shape: [batch_size, height, width, num_classes])
    - y_pred: Predicted labels (shape: [batch_size, height, width, num_classes])
    - smooth: Smoothing factor to avoid division by zero

    Returns:
    - Dice Loss value
    """
    # Flatten the tensors
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)

    # Calculate intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)

    # Compute Dice coefficient
    dice = (2. * intersection + smooth) / (union + smooth)

    # Return Dice Loss
    return 1 - dice

# %% [markdown]
# ## Define model

# %%
model = resnet50_unet(n_classes=3, input_height=544, input_width=736)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94653016/94653016 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# def custom_augmentation():
#     return iaa.Sequential(
#         [
#             # apply the following augmenters to most images
# #             iaa.GaussianBlur(sigma=(0.0, 0.5)),
#             iaa.Fliplr(0.5), # horizontally flip 50% of all images
#             iaa.GammaContrast((0.5, 2.0)),
#             iaa.convolutional.Sharpen(alpha=(0.0, 0.2), lightness=(0.8, 1.2)),
# #             iaa.Grayscale(alpha=(0.0, 1.0)),
# #             iaa.pillike.FilterFindEdges(),
# #             iaa.ShearX((-20, 20)),
# #             iaa.AdditiveGaussianNoise(scale=(0, 0.1*255)),
# #             iaa.Canny(alpha=(0.0, 0.5),colorizer=iaa.RandomColorsBinaryImageColorizer(color_true=255,color_false=0)),
#         ])


# def image_preprocessing(image):
#     image = tf.cast(image, tf.float32)
#     scaled_image = image.numpy() / 255.0
#     return scaled_image

# %%
from keras_segmentation.data_utils.data_loader import image_segmentation_generator, verify_segmentation_dataset
train_gen = image_segmentation_generator(images_path = "/kaggle/input/beach-litter-dataset/Beachlitter_prepped/train_images", 
                                         segs_path = "/kaggle/input/beach-litter-dataset/Beachlitter_masks_litter_only/train_litter_mask",  
                                         batch_size = 2,  
                                         n_classes = 3,
                                         input_height = 544, 
                                         input_width = 736, 
                                         output_height = model.output_height, 
                                         output_width = model.output_width,
                                         do_augment=False, 
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                         read_image_type=1)

val_gen = image_segmentation_generator(images_path = "/kaggle/input/beach-litter-dataset/Beachlitter_prepped/val_images", 
                                       segs_path = "/kaggle/input/beach-litter-dataset/Beachlitter_masks_litter_only/val_litter_mask",  
                                       batch_size = 2,
                                       n_classes = 3, 
                                       input_height = 544, 
                                       input_width = 736, 
                                       output_height = model.output_height, 
                                       output_width = model.output_width,
                                       do_augment = False,
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                       read_image_type=1)

# %%
verify_segmentation_dataset(images_path = "/kaggle/input/beach-litter-dataset/Beachlitter_prepped/train_images",
                            segs_path = "/kaggle/input/beach-litter-dataset/Beachlitter_masks_litter_only/train_litter_mask",
                            n_classes = 3)
verify_segmentation_dataset(images_path = "/kaggle/input/beach-litter-dataset/Beachlitter_prepped/val_images",
                            segs_path = "/kaggle/input/beach-litter-dataset/Beachlitter_masks_litter_only/val_litter_mask",
                            n_classes = 3)
# Out:
# 100%|██████████| 2240/2240 [00:42<00:00, 52.93it/s]
# Dataset verified!
# 100%|██████████| 560/560 [00:10<00:00, 55.87it/s]
# Dataset verified!
# True

# %%
checkpoint_path = "/kaggle/working/weights/resnet50_unet.weights.h5"
os.makedirs(os.path.dirname(checkpoint_path), exist_ok = True)
checkpoint = ModelCheckpoint(checkpoint_path, 
                             monitor="val_dice_loss",
                             save_best_only=True,
                             save_weights_only = True,
                             mode="min")

# %% [markdown]
# ## Model training

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss= 'categorical_crossentropy',#dice_loss,
    metrics=[dice_loss, 'accuracy']#, tf.keras.metrics.F1Score(average = "weighted")] # f1-score, accuracy
)

start_time = time.time()
model.fit(train_gen,
          steps_per_epoch = 512,
          validation_data=val_gen,
          validation_steps=512,
          epochs = 40, # coba 20 epoch u/ cek overfitting
          callbacks=[checkpoint],
          initial_epoch=0)
print('training completed in {} s'.format(time.time()-start_time))
# Out:
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725700383.194082     115 service.cc:145] XLA service 0x7faf78025950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1725700383.194157     115 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1725700383.194165     115 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725700420.887579     115 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_25', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1725700420.933678     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 232s 323ms/step - accuracy: 0.6377 - dice_loss: 0.5650 - loss: 1.0243 - val_accuracy: 0.9482 - val_dice_loss: 0.2364 - val_loss: 0.3418
# Epoch 2/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9233 - dice_loss: 0.2525 - loss: 0.3962 - val_accuracy: 0.9554 - val_dice_loss: 0.1026 - val_loss: 0.1585
# Epoch 3/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9373 - dice_loss: 0.1328 - loss: 0.2226 - val_accuracy: 0.9563 - val_dice_loss: 0.0798 - val_loss: 0.1344
# Epoch 4/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 316ms/step - accuracy: 0.9418 - dice_loss: 0.1005 - loss: 0.1852 - val_accuracy: 0.9590 - val_dice_loss: 0.0765 - val_loss: 0.1258
# Epoch 5/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9426 - dice_loss: 0.0918 - loss: 0.1741 - val_accuracy: 0.9610 - val_dice_loss: 0.0693 - val_loss: 0.1225
# Epoch 6/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9482 - dice_loss: 0.0815 - loss: 0.1554 - val_accuracy: 0.9597 - val_dice_loss: 0.0570 - val_loss: 0.1221
# Epoch 7/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 315ms/step - accuracy: 0.9453 - dice_loss: 0.0820 - loss: 0.1600 - val_accuracy: 0.9534 - val_dice_loss: 0.0687 - val_loss: 0.1278
# Epoch 8/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9538 - dice_loss: 0.0707 - loss: 0.1341 - val_accuracy: 0.9593 - val_dice_loss: 0.0539 - val_loss: 0.1163
# Epoch 9/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 315ms/step - accuracy: 0.9576 - dice_loss: 0.0660 - loss: 0.1241 - val_accuracy: 0.9561 - val_dice_loss: 0.0620 - val_loss: 0.1766
# Epoch 10/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9600 - dice_loss: 0.0606 - loss: 0.1156 - val_accuracy: 0.9555 - val_dice_loss: 0.0600 - val_loss: 0.1283
# Epoch 11/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9587 - dice_loss: 0.0625 - loss: 0.1184 - val_accuracy: 0.9579 - val_dice_loss: 0.0555 - val_loss: 0.1177
# Epoch 12/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9616 - dice_loss: 0.0577 - loss: 0.1089 - val_accuracy: 0.9633 - val_dice_loss: 0.0460 - val_loss: 0.1082
# Epoch 13/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 315ms/step - accuracy: 0.9634 - dice_loss: 0.0550 - loss: 0.1039 - val_accuracy: 0.9608 - val_dice_loss: 0.0497 - val_loss: 0.1149
# Epoch 14/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9659 - dice_loss: 0.0512 - loss: 0.0953 - val_accuracy: 0.9637 - val_dice_loss: 0.0440 - val_loss: 0.1124
# Epoch 15/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9652 - dice_loss: 0.0513 - loss: 0.0977 - val_accuracy: 0.9596 - val_dice_loss: 0.0506 - val_loss: 0.1140
# Epoch 16/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9678 - dice_loss: 0.0480 - loss: 0.0888 - val_accuracy: 0.9622 - val_dice_loss: 0.0446 - val_loss: 0.1159
# Epoch 17/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9706 - dice_loss: 0.0437 - loss: 0.0806 - val_accuracy: 0.9618 - val_dice_loss: 0.0440 - val_loss: 0.1279
# Epoch 18/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9674 - dice_loss: 0.0471 - loss: 0.0897 - val_accuracy: 0.9644 - val_dice_loss: 0.0433 - val_loss: 0.1080
# Epoch 19/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9705 - dice_loss: 0.0430 - loss: 0.0804 - val_accuracy: 0.9560 - val_dice_loss: 0.0523 - val_loss: 0.1411
# Epoch 20/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9726 - dice_loss: 0.0404 - loss: 0.0750 - val_accuracy: 0.9657 - val_dice_loss: 0.0429 - val_loss: 0.1022
# Epoch 21/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9745 - dice_loss: 0.0377 - loss: 0.0698 - val_accuracy: 0.9608 - val_dice_loss: 0.0443 - val_loss: 0.1374
# Epoch 22/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9729 - dice_loss: 0.0399 - loss: 0.0736 - val_accuracy: 0.9623 - val_dice_loss: 0.0457 - val_loss: 0.1157
# Epoch 23/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9744 - dice_loss: 0.0371 - loss: 0.0694 - val_accuracy: 0.9638 - val_dice_loss: 0.0425 - val_loss: 0.1196
# Epoch 24/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 162s 316ms/step - accuracy: 0.9745 - dice_loss: 0.0373 - loss: 0.0688 - val_accuracy: 0.9643 - val_dice_loss: 0.0416 - val_loss: 0.1224
# Epoch 25/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9754 - dice_loss: 0.0358 - loss: 0.0659 - val_accuracy: 0.9623 - val_dice_loss: 0.0435 - val_loss: 0.1233
# Epoch 26/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9773 - dice_loss: 0.0335 - loss: 0.0607 - val_accuracy: 0.9616 - val_dice_loss: 0.0495 - val_loss: 0.1162
# Epoch 27/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9750 - dice_loss: 0.0361 - loss: 0.0663 - val_accuracy: 0.9619 - val_dice_loss: 0.0421 - val_loss: 0.1387
# Epoch 28/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9785 - dice_loss: 0.0313 - loss: 0.0572 - val_accuracy: 0.9617 - val_dice_loss: 0.0432 - val_loss: 0.1373
# Epoch 29/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9771 - dice_loss: 0.0331 - loss: 0.0605 - val_accuracy: 0.9627 - val_dice_loss: 0.0441 - val_loss: 0.1186
# Epoch 30/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 315ms/step - accuracy: 0.9786 - dice_loss: 0.0308 - loss: 0.0563 - val_accuracy: 0.9642 - val_dice_loss: 0.0398 - val_loss: 0.1330
# Epoch 31/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9803 - dice_loss: 0.0287 - loss: 0.0522 - val_accuracy: 0.9631 - val_dice_loss: 0.0426 - val_loss: 0.1265
# Epoch 32/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9800 - dice_loss: 0.0288 - loss: 0.0528 - val_accuracy: 0.9632 - val_dice_loss: 0.0410 - val_loss: 0.1360
# Epoch 33/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 315ms/step - accuracy: 0.9806 - dice_loss: 0.0281 - loss: 0.0509 - val_accuracy: 0.9642 - val_dice_loss: 0.0392 - val_loss: 0.1394
# Epoch 34/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 160s 314ms/step - accuracy: 0.9806 - dice_loss: 0.0278 - loss: 0.0507 - val_accuracy: 0.9633 - val_dice_loss: 0.0421 - val_loss: 0.1296
# Epoch 35/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9806 - dice_loss: 0.0283 - loss: 0.0512 - val_accuracy: 0.9636 - val_dice_loss: 0.0432 - val_loss: 0.1201
# Epoch 36/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9810 - dice_loss: 0.0274 - loss: 0.0493 - val_accuracy: 0.9620 - val_dice_loss: 0.0412 - val_loss: 0.1507
# Epoch 37/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 315ms/step - accuracy: 0.9783 - dice_loss: 0.0305 - loss: 0.0580 - val_accuracy: 0.9653 - val_dice_loss: 0.0386 - val_loss: 0.1325
# Epoch 38/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 161s 314ms/step - accuracy: 0.9811 - dice_loss: 0.0269 - loss: 0.0487 - val_accuracy: 0.9653 - val_dice_loss: 0.0389 - val_loss: 0.1275
# Epoch 39/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 160s 313ms/step - accuracy: 0.9820 - dice_loss: 0.0259 - loss: 0.0471 - val_accuracy: 0.9632 - val_dice_loss: 0.0411 - val_loss: 0.1385
# Epoch 40/40
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 160s 314ms/step - accuracy: 0.9831 - dice_loss: 0.0245 - loss: 0.0437 - val_accuracy: 0.9646 - val_dice_loss: 0.0394 - val_loss: 0.1371
# training completed in 6516.2174553871155 s

# %% [markdown]
# ## Post-processing

# %%
print(model.history.history.keys())
# Out:
# dict_keys(['accuracy', 'dice_loss', 'loss', 'val_accuracy', 'val_dice_loss', 'val_loss'])

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['dice_loss'])
plt.plot(model.history.history['val_dice_loss'])
plt.title('model dice loss')
plt.ylabel('dice loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
out = model.predict_segmentation(
    inp = "/kaggle/input/beach-litter-dataset/Beachlitter_prepped/test_images/002800.jpg",
    out_fname="/kaggle/working/out_mask.png",
    colors = [
    [0, 0, 0],
    [0, 0, 128],
    [0, 128, 0]]#,
#     [0, 0, 128],
#     [128, 0, 128],
#     [0, 128, 128],
#     [128, 128, 128],
#     [64, 0, 0]]
)
plt.imshow(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %%
from IPython.display import Image

o = model.predict_segmentation(
    inp="/kaggle/input/beach-litter-dataset/Beachlitter_prepped/test_images/003036.jpg",
    out_fname="/kaggle/working/out.png",
    overlay_img=True,
    show_legends=False,
    class_names = ["Background", "Artificial Litter", "Natural litter"],
    colors = [
    [128,128,128],
    [0, 0, 128],
    [0, 128, 0]]
#     [0, 0, 128],
#     [0, 128, 0],
#     [0, 128, 128],
#     [128, 0, 0],
#     [128, 0, 128],
#     [128, 128, 0],
#     [128, 128, 128],
#     [0, 0, 64]]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
Image("/kaggle/working/out.png")

# %%
# from IPython.display import Image

# model = resnet50_unet(n_classes=3)
# model.load_weights('/kaggle/input/resnet50_unet/keras/default/1/resnet50_unet_best_2(3)classes.weights.h5')
# o = model.predict_segmentation(
#     inp="/kaggle/input/beach-litter-dataset/Beachlitter_prepped/test_images/002857.jpg",
#     out_fname="/kaggle/working/out.png",
#     overlay_img=True,
#     show_legends=False,
#     class_names = ["Background", "Artificial Litter", "Natural litter"],
#     colors = [
#     [128,128,128],
#     [0, 0, 128],
#     [0, 128, 0]]
# #     [0, 0, 128],
# #     [0, 128, 0],
# #     [0, 128, 128],
# #     [128, 0, 0],
# #     [128, 0, 128],
# #     [128, 128, 0],
# #     [128, 128, 128],
# #     [0, 0, 64]]
# )

# %%
# Image("/kaggle/working/out.png")
